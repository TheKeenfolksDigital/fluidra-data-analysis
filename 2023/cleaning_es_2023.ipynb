# %%
import pandas as pd
from datetime import timedelta

# %%
# Config:
month = 'Jun23'
file_name = 'Spain_Jan_Jun_23'

# %%
# Read CSV with Decimals as comma:
df = pd.read_csv(f"./Inputs/{month}/{file_name}.csv", decimal=',')

# %%
df.head(3)
# Out:
#                   Company (code+name)  Year   Delivery note date  \
# 0  002 - FLUIDRA COMERCIAL ESPAÑA SAU  2023  2023-01-02 00:00:00
# 1  002 - FLUIDRA COMERCIAL ESPAÑA SAU  2023  2023-01-02 00:00:00
# 2  002 - FLUIDRA COMERCIAL ESPAÑA SAU  2023  2023-01-02 00:00:00
#
#    Customer code                             Customer name  \
# 0         101822  SUMINISTROS DE FONTANERIA CASTELLON S.L.
# 1         109055    CLIMAPOOL INSULAR, S.L.U. (LAS PALMAS)
# 2         109233                   M.M. 2004 SERDEMA, S.L.
#
#   Segment code (customer)         Segment name (customer)  \
# 0                      42  HVAC/CONSTRUCT.-Whosale&Retail
# 1                      14       POOL SPECIALIST-Retailers
# 2                      15  POOL SPECIALIST-Instal/Builder
#
#    Global CoFX Amount (net) Sales order number  Order origin
# 0                    639.95             461091            25
# 1                   6077.00             459851            25
# 2                   1399.25             460979            25

# %%
# Renaming Columns:
df = df.rename(columns={'Delivery note date': 'Purchase Date',
                        'Customer Name': 'Customer name', 
                        'Global CoFX Amount (net)': 'Global Amount'})

# %%
df["Customer name"].unique()
# Out:
# array(['SUMINISTROS DE FONTANERIA CASTELLON S.L.',
#        'CLIMAPOOL INSULAR, S.L.U. (LAS PALMAS)',
#        'M.M. 2004 SERDEMA, S.L.', 'ITESA PROYECTOS E INSTALACIONES S.L.',
#        'NOVA RECAL SERVICIOS Y MANTENIMIENTO S.L',
#        'SUPPLAID SUBMINISTRE ASSISTIT, S.L.', 'TU PISCINA EN CASA, S.L.',
#        'FENIX PISCINAS , S.C.', 'PISCINAS DEL ESTRECHO S.L.',
#        'PLASTINIK, S.L.', 'NOVELEC ANTAS S.L.',
#        'FERRETERIA FERROMAR, S.L.', 'CEMENTOS BENIDORM S.A.',
#        'APARISI FERRER, JOSEFA', 'IRRIAGRO S.COOP.V.L.',
#        'GONZALEZ LOPEZ, C.B.', 'CODISNA, S.L.',
#        'GISPERT, DEPURACION DE AGUAS, S.A.',
#        'HIDRO-TARRACO, S.A (PROV. 17050)', 'GARCIA MASIDE, JOSE',
#        'POOLPLUS S.L. (ON LINE)', 'QUIMICOS LOS ABUELOS, S.L.',
#        'SANEAMIENTOS RIGA, S.L.', 'MANEIG PISCINES, S.L.',
#        'ESPAI INTEGRAL DE PISCINES, S.L.(GIRONA)', 'NOMAR R.B., S.L.',
#        'ARROMEL S.L.', 'RIVAS PEÑA,JESUS JUAN', 'LIZASO VERGARA, S.L.',
#        'FERRETERIA LAS NAVES, S.L.', 'TIENDA-PISCINAS  S.L.',
#        'SOLUCIONES TECNICAS MADOS,S.L.U.', 'AQUAFER PISCINAS S.L.',
#        'GUNITEC MALUMAR, S.L.', 'CLIMAPOOL INSULAR, S.L.U. (TENERIFE)',
#        'DEVESA PISCINAS SL', 'PISCINARIUM, S.L.',
#        'LLUCH APARISI, VICENTE (R.E)', 'MERINO PISCINAS, S.L.',
#        'SEGUNDO PRIEGO, S.A.', 'COMERFONSA, S.L.',
#        'SUMINISTRES SEQUIOL S.L.L.', 'PISCI WORLD, S.L.U.',
#        'ELISEO LLABRES  S.A.', 'PRUNELL EGEA, JOSE',
#        'JUPER-BAT,S.A.U. (PROV. 740)', 'CAN PEP PISCINAS, S.L.',
#        'SANEAMIENTOS AXARQUIA S.L.', 'FIBRAGUA ISLEÑA, S.L.',
#        'JOFEG, S.A.', 'BALAUSTRADAS RAMON PASTOR S.L.', 'PRODAGUA, S.L.',
#        'AUXILIAR DE AGUAS Y ALCANTARILLADOS, S.L',
#        'PEPEPOOL ONLINE, S.L.', 'INFLOWED SPAIN, S.L.',
#        'AGUA TECNIC PISCINAS 1994 S.L.',
#        'SANEAMIENTOS FONTICAL ARANJUEZ S.L.U.',
#        'PROAGUA PISCINAS LA VILA S.L.', 'SOTO PUJOLAR, IVAN',
#        'DESCALCIFICADORAS RAYZAR, S.L.', 'ALBAIMTRA S.L.L.',
#        'TECNO PLASTICOS FEYMA,S.L.', 'PISCILIMP,S.L.',
#        'STOCKS PISCINAS, S.L.', 'KELKO QUIMICA S.L.',
#        'FERRETERIA VILANOVA, S.L.', 'TUNEU MUNT, S.L.',
#        'ES-QUIMER XXI, S.L.', 'CLIMAEX ALMENDRALEJO S.L.',
#        'SANEAMIENTOS LOGA, S.L.', 'JU JU JU AQUA CENTER S.L.',
#        'PISCINES VILABERTRAN, S.L.', 'SUCESORES DE MORENO, S.L.',
#        'RIVAS Y ANAYA S.L.', 'AQUASOL MEDIO AMBIENTE S.L.',
#        'RECODER PISCINES MARESME, S.L.',
#        'ANTONIO CABOT FORNES, S.A.(PALMA)', 'CORTES BAYON, OSCAR',
#        'RIGO MALLORCA,S.L.', 'REALOGO S.L.', 'HISEMAR, S.L.',
#        'REAL BLANCA CONSTRUCCIONES, S.L.', 'MAKROAGUA S.L.',
#        'ACTIVIDADES Y SERVICIOS FRAMATVAL,S.L',
#        'A & M INFINITY POOLS S.L', 'COLORADO PERAL,EUGENIO',
#        'CONSTRUCCIONES DEPORTIVAS PROPOOL, S.L.',
#        "TRACTAMENTS D'AIGUA OLOT, S.L.",
#        'SUMINISTROS VALDEPEÑAS 2020 S.L.',
#        'COMERCIAL GUADAGUA 2001, S.L.', 'MANUEL ROMEU,S.L.',
#        'PISCIVAL TECNOLOGIA EN PISCINAS S.L.', 'SERVI RAIN, S.A.',
#        'CAMPOEJIDO, SOC.COOP.ANDALUZA', 'DAUNIS S.A. (PROV. 400001979)',
#        'FANOR, S.L.', 'VICREU, S.A.', 'RIEGOS MELERO S.A.',
#        'F.LAGUNA E HIJOS S.L', 'ROLAND DIJKSTRA',
#        'RIEGOS Y APL. HIDRAULICAS,SAL', 'VERDUGO VAZQUEZ, ISMAEL',
#        'FERROCANO, S.L', 'JARPI PISCINES, S.L.',
#        'AM3 AIGUA EN MOVIMENT, S.L.', 'CORTADO HIGIENE PROFESIONAL, S.L',
#        'PIMACLOR, S.L.', 'BOMBAS Y GRUPOS ALZIRA,S.L',
#        'GRUPO LARA PROYECTOS, S.L.', 'SOCIAS Y ROSSELLO,S.L.',
#        'INNOVACION TECNICA PISCINAS SL',
#        'PISCINAS CANALES S.COOP.PEQUEÑA', 'NOVOSAT POOL, S.L.',
#        'GRUPO ESPIRAL EFICIENCIA CONSTRUCTIVA,SL',
#        'FONTIA SUMINISTROS S.L.(ON-LINE)',
#        'PRODUCTOS LC LA CORBERANA S.L.', 'AGROMASAN S.L.',
#        'J.J.J.PISCINES SANT FELIU, S.L.', 'PISCINES DOME,S.L.',
#        'COMERCIAL RAMSER, S.A.', 'FERRET.Y MAT.ELECTRICO URBANEJA S.L.',
#        'HIDROSYSTEMS MALLORCA, S.L.', 'SANEAMIENTOS DIMASA, S.L.',
#        'EXTERIOR PISCINES,S.L.', 'SPA Y PISCINAS IBIZA, S.L.',
#        'HIDROLIA S.L.', 'FLUIDWATER S.L.U.', 'HIDROBALEAR, S.L.',
#        'EIX PISCINES, S.L.', 'URTEAGA POOL CONCEPT, S.L.U.',
#        'GRUPO ELECTRO STOCKS(FLUIDSTOCKS IBIZA)', 'BOMBAS IDEMUR, S.L.',
#        'JUBERT I VILA COMERCIAL, S.L.', 'PISCINAS ISLA S.L.',
#        'PREBLAU, S.R.L.', 'GARRIGA CANET, S.L.',
#        'AIGUALLUM DE PONENT, S.L.', 'PISCINES CERVELLO, S.L.',
#        'DANVAL POOL GARDEN, SL', 'COPIL, S.L.',
#        'ACCESORIOS Y TECNICAS DEL AGUA S.L.',
#        'MUSACO TECNOLOGIA I AIGUA S.L.', 'PISCINAS URATEK, S.L.',
#        'PISC.E INST.DEPORTIVAS CAUDAL GALICIA SL',
#        'PROFESIONAL POOLS S.L.', 'LOPEZ MENDEZ,CARLOS (MAKROPISCINAS)',
#        'COMERCIAL MORENO 2000 SL',
#        'SUMINISTROS INDUSTRIALES D TALAVERA,S.L.', 'POOL-JARDIN,S.L.',
#        'AZULEJOS BARMA S.L.', 'PISCINAS MD PORTMANY,S.L', 'JULYPOOL S.L.',
#        'PROTEO, S.L.', 'HIDROBOMBA, S.L.',
#        'GRANADINA DISTRIBUCIÓN MATERIAL S.L.', 'SERRATO LUZ S.L.',
#        'PISCINES GELMI, S.L.', 'SUMINISTROS E INSTALACIONES VALIRA, S.L.',
#        'WORLDFER POOL S.L.', 'TENERIFE EUROPOOL, S.L.',
#        'SUMINISTROS BERMUDEZ ULLOA, S.L.',
#        'PROYECTOS E INSTALACIONES CLIMAPOOL,S.L.',
#        'FONTIA SUMINISTROS S.L.', 'AQUAVI PISCINAS S.L.',
#        'PLANETRANSPARENTE PISCINAS UNIP.LDA.E.P.',
#        'CALDERERIA PLASTICA LUMIPLAS SL',
#        'PRAT POLIESTER PISCINES. S.L.U.',
#        'DEVESA TECNICAS Y COMERCIO S.L', 'ESMUNAS, S.A.',
#        'PISCINAS ESPALMADOR, C.B.', 'SANEAMIENTOS AVILA, S.A.U.',
#        'PROPAGUA DEL LEVANTE 2007, S.L', 'NATUR CLARA, S.L.',
#        'PISCINAS Y SPAS POOLNATURAL S.L.', 'TESWATER GLOBAL S.L.U.',
#        'SUBMINISTRES ABC SABADELL, S.L.', 'CASTRO DIAZ, MARIA TERESA',
#        'LOGISTICA URBANA AMBIENTAL', 'ALVAREZ RODRIGUEZ DAVID',
#        'PISCINAS CAS CAMPANE, S.L.', 'CABAÑERO ARAQUE,JUAN MIGUEL',
#        'PESA WELL ENGINEERING S.L.', 'PLAYTENIS S.L.',
#        'FRANSA AGROQUIMICOS S.L.', 'SANEAMIENTOS PEREZ CARRASCO,S.L',
#        'RUBI NICOLAU, JUAN', 'LLADOPOL, S.L.',
#        'SABORITO BOLIVAR, JOAQUIN', 'SUMINISTROS GUALLAR, S.L.',
#        'PISCINAS JESUS,S.L.', 'HERMANOS MEDINA UNGUETTI S.L.',
#        'SERVICIOS ACUATICOS Y MTO. GIJON 2005,SL',
#        'DABAU GESTRANEM, S.L.', 'GOTAGUA SYSTEMS S.L.',
#        'TECNOLOGIAS DEL AGUA BARREIRO, S.L.',
#        'HERMANOS SANJOSE CONSTRUC. Y DISEÑO. S.L', 'KOAN IRRIGATION S.L.',
#        'INSTALTEC EMPORDA, S.L.', 'FONTANERIA FERNANDEZ LUNA S.L.',
#        'RIEGOS CLIMENT S.L.', 'RIEGO SUR DE MONTAJES S.L.',
#        'STAFF PISCINAS, S.L.', 'SAGUE I CLARA, JOAN', 'ALWAZGARY S.L',
#        'HIGIMAN S.L', 'PISCINAS MANTENIMIENTOS MALLORCA, SL',
#        'AQUAINDESA, S.L', 'EMPORDA POOL, S.L.',
#        'JUAN MARQUEZ DEL RIO S.L.', 'ESPACIOS TERMOLUDICOS ,S.A.',
#        'PISCINES ATLANTIC 2014, S.L.', 'OCEAN POOL SERVICE, S.L.(TIENDA)',
#        'CYSPOOLS, S.L.U.', 'SANEAMIENTOS SAN ANTONIO DE CUENCA S.L.',
#        'SUMINISTROS GRIÑON, S.L.', 'DEPUR-CLOR, S.L.',
#        'CONSTRUCCIONES DEPORTIVAS SADA, S.L.', 'PISCINAS VIGO, S.L.',
#        'ORTEGA GIL, NESTOR', 'JOAQUIM URPI,S.L',
#        'INSTALACIONES BARBER GOMILA, S.L.', 'SUAREP Y LLADO, S.A.',
#        'FERRON LOGISTICA, S.L.', 'AIGUAMBIENT SOLUCIONS S.L.',
#        'AIRE ANCIENT BATHS S.L.', 'AGRIISSO, S.L.', 'SORRIBES LUJAN,S.L.',
#        'FON ELECTRIC, S.A.U.', 'DE FELMA, S.A.',
#        'GRUPO SPAZI AGUASPORT, S.L.U', 'HERMANOS MARTINEZ PORTERO C.B.',
#        'ACTIVA GESTION INTEGRADA DE A.E.P S.L.',
#        'BERAL PROJECTS, S.L. (OUTLET PISCINAS)',
#        'SUMINISTROS JOSE LUIS CABRERA,S.L',
#        'SUMINISTROS DOMINGUEZ AGUILERA ELDA S.L', 'DISFOTEN 7 ISLAS S.L.',
#        'AQUADRIVE, S.L.', 'GRUPO ELECTRO STOCKS(FLUIDSTOCKS VALENC)',
#        'DESJOYAUX IBERICA, S.A.', 'PISCINES RICARD,S.L',
#        'SUMINISTROS CALEFON, S.L.', 'PISCINAS SOTO S.L',
#        'TUBERAGUA SUMINISTROS, S.L.', 'PISCINAS RAMIREZ S.L.',
#        'RENTDELUXE, S.L.', 'COMERCIAL GALAN, S.A.',
#        'EURO PLASTICOS TEC.IND.QUIM.S.L.',
#        'MANUFACTURES DEL P. GRAU-FARRES, S.L.',
#        'PEDRO CAMPANER CAPLLONCH(JARDINS CAMPANE', 'ORMOTA S.L.',
#        'FONRIVE C.B.', 'MATA CARRASCOSA, VICENTE',
#        'AQUAENOL OBRAS Y PROYECTOS S.L.', 'NORD ARBONA,S.L.',
#        'J.PARRILLA,S.A.', 'AQUAPRIMO SOCORRISMO OCIO Y DEPORTES SL',
#        'COMERCIAL AGROCOR, S.L.', 'ALMACENES CALINDSA, S.L.',
#        'SUNTEX S.L.', 'BOMBAS HIDROSEGURA, S.L.', 'DEMS - IHF, S.L.',
#        'FONT-MECO S.L.', 'JOSE GARCIA E HIJOS DE LEPE S.L.',
#        'RIEGOS MANACOR, S.L.', 'TODOCLIMA RENOVABLES, S.L.',
#        'ALFA 90 SUMINISTROS Y SERVICIOS ,S.L.',
#        'SUMINISTROS MILLAN GARCIA S.L.', 'AZNAR CANAL, CARMELO',
#        'ASSENZA, PEDRO MAURICIO', 'SANEXABIA SANEAMIENTOS S.L.',
#        'PISCINES FIGUERES, C.B.', 'AITOR J. MATEU, S.L.',
#        'FONTANERIA GAVILAN S.L.', 'HIDRO-SPORT CONSTRUCCIONES, SL',
#        'ESTOL 2.005, S.L.', 'METALUX ASTURIAS S.L.',
#        'PISCINAS SALNES, S.L.', 'M. DEL RIO E HIJOS, S.A.',
#        'MP IRRIGATION, S.L.', 'INDUSTRIAS ARGUI,S.A.',
#        'FONTANERIA ANAMAR, S.L', 'TECNODRY CANARIAS, S.L.U.',
#        'ECIMAN, S.L.', 'SAN ANTONIO LLORENS, FERMIN', 'PORINOX, S.L.',
#        'TAUMAU FACILITY SERVICES, S.L.', 'DEYCON PISCINAS, S.A.',
#        'NEDAPOOL, S.L.', 'CALPE IMPERM. Y PISCINAS, S.L.',
#        'AZALEA PROYECT AGRICOLAS Y JARDINERIA SL', 'PISCIGRES S.L.',
#        'ANTEQUERA Y RAMON S.L.', 'ENREJADOS DE GALICIA S.L.',
#        'POOLPLUS S.L. (TIENDA ELCHE)', 'CIRILO LOPEZ SERRANO, S.L.',
#        'VICENTE CALABUIG, S.L.', 'PISCINES BLANES, S.L.',
#        'HIDROINGENIA S.L.', 'JARDINES CAMPANER S.L.U.',
#        'BLAUBIS PISCINAS,SL.', 'AQUADYNAMICS SERVICIOS GLOBALES S.L.',
#        'PISCINAS PRESSING, S.L.', 'PISCINAS RUBIO, S.L.',
#        'TECNIELMA S.L.', 'MATERIALES DE CONSTRUCCION ODORICIO S.L.',
#        'BIPACOM S.L.', 'FERNANDEZ DIAZ , JOSE MARIA',
#        'ALMACENES GUADALOPE HOSTELERIA, S.L.',
#        'SONEPAR IBERICA SPAIN S.A.U (SONEPAR)',
#        'DEPURADORES KRISVAL S.L.', 'TURIA-REGS S.L.', 'GERSAL, S.A.',
#        'ELECTRICA PUIGCERCOS, S.A.', 'G.R. RIEGOS, S.L.',
#        'PROLIVER TRATAMIENTOS Y GESTION S.L.U.', 'BLUEFOREVER, S.L.',
#        'AGUANORTE PISCINAS Y OCIO, S.L.', 'PRADO PLANTEL, S.L.',
#        'MECAAN INGENIERIA Y PROY. HIDRAULICOS,SL',
#        'INGENIERIA Y BIOGAS, S.L.',
#        'SANIPLAST SOLUC.S.DEL AGUA SL (BESOS)',
#        'PLASTICAL TECNOLOGIAS E INGENIERIA S.L.',
#        'COREMA COSTA 2006, S.L.', 'SANCHEZ MOYA, GONZALO',
#        'SIMO FOLCH, Mª JOSE (R.E.)', 'AQUARRUBIA, S.L.', 'KIMI, S.L.',
#        'ANTONIO SARMIENTO S.L.', 'VELAZQUEZ DE CASTRO URREA JUAN',
#        'PISCINES BRAVI, S.L.', 'PISFRILAN, S.L. (CANARIAS)',
#        'TECNOSPORT INTERNACIONAL, S.A.',
#        'DISTRIBUIDORS EUROPA DE MENORCA, S.L.', 'FERRETERIA VALLS, S.L.',
#        'BIBOAQUA, S.L.', 'AUTOSERVICIO LA LLAVE, S.L.',
#        'PISC.SERVIC. Y CONS.VARELA S.L.',
#        'INSTALACIONES Y SUMINISTROS IRRIGATIO SL',
#        'MATERIALES SENTANO, S.L.', 'PISCINAS PILIO S.L.',
#        'REMARSA RIOJA S.L.', 'AQUATIKA PISCINAS S.L.U.',
#        'PISCINES ARGENTONA, S.L.U.', 'DOMAR SISTEMAS S.L.',
#        "COTA TRACTAMENTS D'AIGUA, S.L.U.", 'ELECTROBOMBAS JAVEA, S.L.',
#        'BOINS S.L.', 'URTEAGA QUIMICA, S.L.U.',
#        'COMERCIAL POL.SAN RAFAEL, S.A.',
#        'SUMINISTROS INDUSTRIALES HIDROMAR, S.L.', 'ACQUABAENA S.L.',
#        'AGROREPUESTOS LEVANTE S.L', 'HOME & GARDEN IMPORTS S.L.',
#        'PISCINAS ZENPOOL S.L', 'VECOBAY S.L.',
#        'ALBORAN PISCINAS GROUP S.L.', 'CONSTRUCCIONES PAMA, S.A.',
#        'DISEÑO Y TRANSFORMACION DE POLIESTER,S.L',
#        'MASCARO, SUMINISTRES I SERVEIS, S.L.', 'BOBIMAT, S.L.',
#        'SUMINISTROS MAEZTU, S.L.', 'FONTALMANZORA S.L.',
#        'PISCINAS UNIC, S.L.', 'MAZA SANGUESA, LUIS MIGUEL',
#        'PRODESA DESING,PROYECT & CONSTRUCCION SL', 'POOLS & MORE, S.L.',
#        'ANIP LEVANTE, S.L.', 'COMERCIAL MOSABE S.L.', 'NEW CHEM S.L.',
#        'GRUPO WELLTECH 94, S.L.',
#        'SUMINISTROS DE FONTANERIA MARCAL, S.L.', 'BIENDA, S.A.',
#        'PISCIPOOL, S.L.', 'GESTION Y ADMINISTRACION DEPORTIVA, S.L.',
#        'NOVELEC ILERDA, S.L.', 'MA&MA POOL, S.L.', 'AROUSA, S.L.',
#        'PISCINAS MIÑO, S.L.', 'TODOCAMPO DEL SUR S.L.U.',
#        'AGROISLEÑA SUMINISTROS S.L.', 'BELEN FERREIRO, ANA',
#        'J.L. MARDARAS E HIJOS, S.L.',
#        'BEST WATER TECHNOLOGY IBERICA, S.A.U.', 'GRANETS MONTGRI, S.L.',
#        'ENVASES DE GALICIA, S.A.',
#        'INSTALACIONES DE CONTROL BACTERIOLOGICO',
#        'VARA MADURGA, FERNANDO JAVIER',
#        'PROYECTOS Y SERVICIOS INTEGRALES SUR SL', 'ROLORTE, S.L.',
#        'PISCINAS RAYMI, S.L.', 'BALNEARIO MAS SALAGROS S.L.',
#        'CASQUEIRO MARTINEZ, IRIA', 'SUMINISTROS COPLASA S.L.',
#        'GESTION MATERIALES Y SERVICIOS S.L.', 'DACLE S.L.',
#        'GODO POOL DEVELOPMENT S.L',
#        'CONSTRUCCIONES ALEJANDRO DE BEJAR, S.L.U', 'CORRALO, S.L.',
#        'PROYECCIONES AQUA, S.L.U.',
#        'ESTEVAL S.A.L (SERVICIOS TEC.VALENCIANOS',
#        'LERIDANA DE BOMBAS Y MOTORES.S.L', 'PISCINES DODAS, S.L.',
#        'CONSTRUCCIONES ZABALETA BURGUI, S.L.',
#        'PROYECTOS Y CONST. ARCOBUR 2016, S.L.',
#        'NAVAPOOL MANTENIMIENTO INTEGRAL S.L', 'ISOWO SERVICES SLU',
#        'GUNITADOS CINCO VILLAS, S.L.', 'C.E.I. COM. ELEM. INDUSTRIA SL',
#        'DICELTRO GARRAF, S.L.', 'PISCINAS MON DE PRA,S.L.',
#        'MANUFACTURAS PORTILLO,S.L', 'ABC POOL PALMERA S.L.',
#        'NOVELEC GRANATUM S.L.',
#        'DISTRIB MAYORISTAS HIDRO DEL SURESTE S.L', 'SAYPOOL ADRYSS S.L',
#        'LIMPIAFONDOS ONLINE S.L.U.', 'GIMNASIARCA, S.L.',
#        'SUMINISTROS ALARCON, S.L.', 'PRODUCTOS DE LIMPIEZA JOSBAR, S.L.',
#        'QUIMICOS COBOS MEGIAS S.L.', 'RECODUL, S.L.',
#        'PREMIUM POOL AUSTRALIA S.L.',
#        'PISCINAS MEDITERRANEO AGUAMAR S.L.', 'MEDINA OFRETORIO, KOLDO',
#        'GUTIERREZ MARTINEZ, ANDRES IVAN', 'A. PALLISER, S.L.',
#        'SPORT STUDIO SERVICIOS DEPORTIVOS S.L.',
#        'MULTISECTORIAL ITEMO S.L.U.', 'GAUDI PISCINAS GARRAF, S.L.',
#        'JUAN LORENTE GARCIA, S.L.', 'JAEN CLIMA S.L.',
#        'WUBBOLTS MARCELLUS, ANTONIUS W.',
#        'INBECA WELLNESS EQUIPMENT, S.L.', 'CRAMA BRT S.L.',
#        'SPACE POOLS COMPOSITES, S.L.U.', 'LLATJE ELECTROHIDRAULICA, S.L.',
#        'REVOLUTION STAR. S.L.', 'MARTINEZ GARCIA, AROESTI',
#        'PAISAGISMO DEL VALLES, SLU', 'ROMAN BORDAS, JUAN JOSE',
#        'OCEAN POOL SERVICE, S.L.(OBRA)', 'PISCINAS ALCAZAR C.B.',
#        'TEYMAGUA, S.A.', 'IMPER SERVEIS COMAS, S.L.',
#        'DETERGENTS BURGUERA S.L.', 'EXCLUSIVAS GIBALTO S.L.',
#        'PISCINAS MIGUEL S.L.', 'SOTEC LUIS CROVETTO S.A.',
#        'MANAGA CONSTRUCIONES Y CONTRATAS,S.L',
#        'HEREDIA DOMINGUEZ,FERNANDO', 'AGUA SOLUCION 21, S.L.',
#        'TOP PISCINES S.L.', 'COMERCIAL BASTOS, S.L.',
#        'RIEGOS HUERTAS, S.L.', 'GUNITADOS MENORCA, S.L.',
#        'INSTALACIONES DEPORTIVAS NORTE S.L.', 'SANEAMIENTOS CRUZ S.L.',
#        'ASISTENCIA TECNICA CATALANA, S.A.', 'CEBALLOS CARRERA, CARLOS',
#        'GOYVAL VINAGRES S.L.', 'BOSQUE URBANO, S.L.',
#        'GARCAM INDUSTRIES, S.L.U.', 'RIEGOS AUTOMATICOS RUIZ S.L.',
#        'NUVI ARABA, S.L.', 'PISCINOR, S.L.',
#        'SERVICIOS Y MANTENIMIENTOS TEMPUL S.L.',
#        'SUMINISTROS Y SERVICIOS TERMALDE, S.A.', 'FONTASOL,S.L.',
#        'AGUA Y ESPACIOS NATURALES S.L', 'AQUS POOLKIT S.L.',
#        '**LOPEZ CORBALAN, ANTONIO', 'PISCINAS Y CALEFACCION DIALSA, SL',
#        'MONAGUA, S.L.', 'AQUALAR PISCINAS S.L.',
#        'VIGAS GOMEZ, DANY ALBERTO', 'TUBESAN S.L.',
#        'JUAN FRANCISCO ALCAZAR S.L.', 'LINDAMER, S.L.',
#        'A.Q.A. EQUIPS, S.L.', 'HIDROTECNIC NUEVAS TECNOLOGIAS SL',
#        'ARANDA LATORRE, MARIA DOLORES', 'TEKTHINGS, S.L.', 'SOLVE IMI',
#        'MATERIALS FONTANERIA I SANITARIS,S.L.', 'ASSEMBLY Y POOL, S.L.U',
#        'TOBAXA SANEAMIENTOS DE LA AXARQUIA S.L.',
#        'SUMINISTROS FRESNEDA S.L.', 'RODRIGUEZ OLMOS, S.L.',
#        'MONTAJES Y SERVICIOS AGROCAS S.L.', 'NOU SITAN S.L.',
#        'TORCALAGUA S.L.', 'BENITO GARCIA AGUILAR E HIJOS, S.L.',
#        'GESTION DE RIESGOS AMBIENTALES S.L.', 'COMERCIAL DURMA, S.L.',
#        'CATALA CABALLER, JOSE GUILLERMO', 'SAEZ DE TEJADA S.A.',
#        'ELECTRICA RIAM, S.A.', 'MOLINA PINADERO, JAVIER',
#        'MONTES TORRES S.L', 'HIDROFIL HIDRAULICA Y SUMINISTROS, S.L.',
#        'EXPERT POOL IBERICA S.L.', 'APSU POOLS S.L.U',
#        'POOL & GARDEN GB INST Y SERV SL', 'AVILA-BOSCH, S.L.',
#        'CAULAS CASADEVALL, NARCIS', 'ISABA PROJECTS, S.A.',
#        'BRYCUS HOME & GARDEN, S.L', 'HIDROCAEX S.L',
#        'ORTIZ ORTIZ, DOMINGO', 'SANEAMIENTOS HERMANOS BLANCO, S.L.',
#        'G I G PISCINES, S.C.', 'SILVASOL ENERGIA,SISTEMAS Y SERVICIOS SA',
#        'PISCINAS MARIN S.L.', 'PISCINAS TXUKUN, S.L.',
#        'SANCHEZ HERNANDEZ, MIGUEL ANGEL',
#        'ANTONIO CABOT FORNES,S.A.(IBIZA)', 'RODRIGUEZ PIVA, S.L.',
#        'PONS ONDARA, S.L.', 'JARPIS, S.L. (ON LINE)', 'SANIAGUA, S.L.',
#        'DEPURACIONES VELA, S.L.', 'INTER-VAP EUROPA S.L.U.',
#        'INSTALACIONES RASU S.L.', 'EUROSTAR NUEVOS NEGOCIOS, S.L.',
#        'GLOBAL BLUE INK S.L.U.', 'SOMI PIPE AND FITTING S.L.',
#        'ANTONIO CABOT FORNES,S.A.(MENORCA)',
#        'SUM.GONZALEZ E HIJOS S.L.-OLIVA-', 'GARDEN EGARA, S.L.',
#        'COMERCIAL CAULES, S.A.', 'CIAL. A. COSTAS FERNANDEZ,S.L.',
#        'CASA TECNICA GOETZ S.L.', 'AGALI, S.L.U.',
#        'BOMBAS BENEDICTO GIL, S.L.', 'HIDRITEC WATER SYSTEMS, S.L',
#        'GRUPO CORAL LEVANTE, S.L.', 'LISARDO DORRIBO CAMBA, S.A.',
#        'J. HUESA WATER TECHNOLOGY, S.L.U', 'FUTURQUIMIA, S.L.',
#        'CIAL. SANTANA ALEMAN Y GONZALEZ, SL', 'MARIPOL & ROYAL, S.L.',
#        'OLAQUA PISCINAS, S.L.', 'EDL CREATIVE WATER, S.L.',
#        'INFOAGUA CONTROL Y PREVENCION  SL', 'BOBINADOS GARRAF, S.L.',
#        'HNTOOLS,SL.', 'FONTANERIA Y CALEFACCION CASPER, S.L.',
#        'ESPACIO HIDROTERMAL, S.L.', 'LEISIS S.L.',
#        'COLABORADORES DE LAS ADMIN.PUBLICAS S.L.',
#        'PISCINAS IGUAZU, S.L.', 'HIDALGO Y RECIO, S.L.',
#        'SHOBAI TECHNOLOGIES, S.L.', 'ALMAR PISCINES, S.L.',
#        'GARCIA NOGUES, FRANCESC', 'POSEIDON WATER SYSTEMS, S.L.',
#        'CANO MAYORGAS, IVAN', 'CUESA SPORT, S.L.',
#        'PISCINAS JIMENEZ, S.L.', 'GERCO ASTUR, S.L.(MALAGA)',
#        'A CAMPIÑA DE LEMOS, S.L.', 'ELECTRO MEYRAS S.L.',
#        'MANTENIMIENTO Y REFORMAS IBIZA, S.L.',
#        'CONSTRUCCIONES ISEL MARBELLA S.L.U', 'MIGUELEZ MAYORAL, ALBERTO',
#        'MOYPE SPORT, S.A.', 'GRUPO ANTOLIN INSTALACIONES,S.L.',
#        'LIMFOR FORMENTERA, S.L.', 'PLAREX, S.L.',
#        'VELARDE APARICIO, Mª CARMEN', 'BRICOCENTRO LLOMGAR,S.L.',
#        'QUALITY FERRET. PLUS,SCCL(F.SANT MIQUEL)',
#        'AISLANTES AISLAMAX, S.L.', 'ACCESSORIS SENCOR,S.A.',
#        'CONSTRUCCIONES RELLINARS, S.L.',
#        'TECNOLOGIAS SOLARES DEL MEDITERRANEO S.L',
#        'BONGRUP BALEARES, S.L.', 'DAVA, S.A.', 'EBREPOOL, S.L.L.',
#        "HOTELES MARINA D'OR S.L.", 'SILLERO E HIJOS , S.L.',
#        'RODRIGUEZ-ARIAS IZARD, JULIO (RE)', 'CABADAS ALVAREZ, ALEJANDRO',
#        'CANARY SERVE SERV.INTEGR. SL', 'CAMPEÑA DE PISCINAS, S.L.U.',
#        'VISANFER S.A.', 'CONTRATAS INTEGRALES CAMILMARC, S.L.',
#        'SUMINISTROS DOMINGUEZ AGUILERA, S.L.', 'HYDRO GLOBAL, S.L.',
#        'PISCINES CREIPOL, S.L.U.', 'EQUIDESA GROUP S.L.',
#        'CAMINGITEC, S.L.', 'SID PISCINAS E INSTALACIONES S.L.',
#        'SERVIDAYA, S.L.', 'SUMINISTROS BARBANZA, S.L.', 'BOSGRIF  S.L.',
#        'FONROCAL S.L', 'SUMYMAQ LEVANTE 2004 S.L.', 'SIDERAL 2007, S.L.',
#        'PISCIVALEN 2020 S.L.', 'CONTROL POOL S.L.',
#        'INVERSIONES ANYPA, S.L', 'AQUAMADRID PISCINAS, S.L.',
#        'UNION TORRE LORCA S.A', 'FLUME, S.L.', 'ASSUR PISCINAS, S.L.',
#        'MOTORS I BOMBES VIDAL, S.L.', 'PISCINAS Y PROYECTOS VIDALMAR SL',
#        'MERCADO OLLERO, Mª DEL CARMEN', 'BRAVO MORA. JOSE LUIS',
#        'SUMINISTROS NAVARRO,S.A.', 'MIRO I GUEVARA HIDROTEC, S.C.P.',
#        'BOMBA CORAL, S.L.', 'ELITE STORE PROYECTOS Y DECORACION, S.L.',
#        'ADIQUIMICA,S.A.', 'PACHON CAMPOS, DANIEL', 'PROGASCA, S.L.',
#        'HIDRIC ONLINE, S.L.U.', 'VIAGUA, S.L.',
#        'EUROACUATICAS 2002 S.L.L', 'SANCHEZ ROSADO, MARCOS',
#        'GENERAL DE PISCINAS POZOBLANCO S.L.', 'JORDI INSTALACIONES S.C.',
#        'SICART CASELLAS, AUSIAS', 'NAVARRO A.T.H., S.A.',
#        'SUMINISTROS INDUSTRIALES ARNALDOS S.L', 'VIDA PALOMO, MIGUEL',
#        'PISCINES I PAISATGES, S.L.', 'SERVIEMPORDA, S.L.',
#        'BERROJALBIZ E HIJOS, S.A.', 'ZALTARI SERVICIOS S.L.',
#        'MAGATZEM ADROVER, S.L.', 'CAUDAL SUR, S.L', 'GRUPO PUYA 68 S.L.',
#        'BUENDIA LEYVA, ANTONIO', 'OZONIO NOVA XXI, S.L.',
#        'FONTANERIA ALFONSO, S.C.', 'TECNOMERCIAL MACARONESIA SL',
#        'AQUARIUM, S.L.', 'SISTEMAS DE ENVASADOS FILL PACK S.L.U.',
#        'FONTYREG MANACOR,S.L.', 'POOLS CONSULTING & WATER S.L.',
#        'CONSTRUMA COSTA BLANCA, S.L.', 'AIGOSAN S.L.',
#        'C.A.3 PISCINAS SL', 'MARTINEZ MENDIGUCHIA,JOSE RAUL',
#        'HERMANOS PLAZA BRAVO, S.L', 'MIGUEL CABELLO ELENA S.L.',
#        'PISCINAS ZURITA S.L.', 'DOINSA HISPANIA, S.L.',
#        'HORTALIZAS BACELO, S.L.', 'ALMERIA AGUA CONFORT S.L.',
#        'PISCINAS POOLS POLLENÇA, S.L.', 'LORENZO INGEX, S.L.',
#        'IGLAR SOLUCIONES ENERGÉTICAS SLU',
#        'SUMINISTROS GAS MARTINEZ, S.L.', 'SUMINISTROS SANTAGATA, S.L.',
#        'Q TECH HOUSE DIVISION SLU', 'AQUA BLAU SOLUCIONS, S.L.',
#        'TEKNIK SUMINISTROS 2012,S.L.', 'INSTALACIONES CORUMBEL S.L.',
#        'AC PISCINA REFORMA Y JARDIN, S.L.', 'UNION COPIMAR, S.L.',
#        'INSMAN TOBARRA S.L.', 'FERR.D.HERNANDEZ E HIJOS,S.A.',
#        'HIDRORIOL, S.L.', 'COLLADO DIAZ, MANUEL',
#        'HIDRAULICA TINERFEÑA,S.L.(TENERIFE)', 'RECHE GARCIA, OSCAR',
#        'IXOS CEALCO S.L.(TAUSA)', 'CONSTRUCCIONES PISCIESPORT, S.L',
#        'AFMJARDINERIA S.L.', 'PEREIRA GAMEZ, JOSE LUIS',
#        'TASIES VALEN, FRANCISCO', 'AVELLANEDA RODRIGUEZ, DANIEL',
#        'GARDEN POOL SANTO DOMINGO, S.L.', 'CISLA, S.L.',
#        'SURPOOL PISCINAS,S.L.', 'DURPLASTICS, S.A.',
#        'SUMINISTROS IBIZA DE INVERSIONES Y C. SL', 'FONTIMAT, S.A.',
#        'INGENIERIA DE AGUAS DEL SUR S.R.L.', 'PINTEGA XARDINS S.L.',
#        'GRUPO ELECTRO STOCKS(FLUIDSTOCKS MURCIA)',
#        'NEOPRO SER. INT. DE FERR.,SL(F.SANT MIQ)',
#        'PISCINAS SAN ANTONIO,S.L.', 'INSTALACIONES CLASSIC S.L.',
#        'IASUR AGUA, S.L.U.', 'QUIMIAGUA NORTE, S.L.',
#        'OANCEA, IOAN MARIUS', 'ZAFRA YUSTE, GUILLERMO',
#        'GONZALEZ GESTOSO, JACINTO', 'COSTA DE AZAHAR MES NET S.L.',
#        'MAQUINARIA AGRICOLA CARPINTERO S.L.', 'MONTERO LASTRES, MAXIMINO',
#        'POOLGROUP, S.L.', 'SUM.SANITARIOS Y FONTANERIA SL',
#        'RODRIGUEZ BONASTRA, GEMMA', 'PISCINAS AQUAMAX, S.L.',
#        'SUMIPON, S.L.', 'COJARDIN, S.L.',
#        'FRUTOS LOPEZ GALINDO GRUPO, S.L.', 'SIPE MATERIALS, S.L.L.',
#        'NOVELEC EMPORDA, S.L.', 'CONSTRUCCIONS GERMANS RODEJA, S.L.',
#        'SEMILLAS Y PLANTAS ESCOLAR, S.L.', 'REGS ALMENARA C.B.',
#        'M.C.R. DIELEC S.L.', 'RIEGOS SIRIA ,S.L', 'MULA HERNANDEZ S.L.',
#        'RODA  P & Q, S.L.', 'ROS FRIO Y CALOR, SL', 'QUIMIAGUA SUR S.L.',
#        'VILLERGAS CANTOS, RICARDO', 'BONA PEREZ, MIGUEL',
#        'SANEAMIENTOS LUENGO, S.L.', 'COMERCIAL MONCHO S.L.',
#        'GOMEZ MUÑOZ, SANDRA (RE)', 'FENTO JARDIN S.L.',
#        'AGRICOL INSTALACIONES, S.L.', 'SANEAMIENTOS ENRIQUE GARCIA,S.A.',
#        'ARGYSAN,  S.L.', 'LLADOS PICATOSTE, GERARD',
#        'SUM.GENER.FONT.Y SAN.GESA S.L.', 'ORENQUIMICA, S.L.',
#        'FERNANDEZ MILLAN, JESUS MARIA', 'TUBOSA BALEAR. S.L.',
#        'LOS BARREROS VIEJOS, S.L.', 'POOL AESTHETICS S.L.',
#        'VIDAL SILVESTRE, JOAQUIN', 'GRUPOVALMI, S.L.L.',
#        'DIELFON COSTA S.C.A', 'REYMAN ELECTROBOMBAS, S.L.',
#        'CARLOS ALCARAZ S.A.', 'CONRADO Y ASOCIADOS ,S.A.',
#        'CONSTRUCCIONES EN INOX. PISCINOX, S.L.',
#        'BLANYVAN TOTAL POOL S.L.', 'SOLUC.INTEG.EFIC.Y TECN.EDIF.SL (FC)',
#        'AQUACOM SANEAMIENTOS, S.L.', 'SUTECNO S.L.',
#        'CHAVEZ GONZALEZ ALFREDO', 'MOLINA ROMAN, MIGUEL',
#        'CLUB NATACION SANT CUGAT', 'MARTORELL DAROCAS, ALBERTO',
#        'PREFABRICADOS MAFER, S.A.', 'ACONAGUA 2000, S.L.',
#        'ORTIZ HINOJOSA, JUAN FRANCISCO',
#        'MERKAMAT SUMINISTROS Y AZULEJOS, S.L.',
#        'NEW FRICAL IBERICA, S.L.',
#        'TECNICAS DEL AGUA CES-BELINCHON, S.L.',
#        "AQUALITICS, TRACTAMENTS D'AIGUA, S.L.", 'SIERRA ZAPATA, NURIA',
#        'MACROTUBO, S.A.', 'INSTALACIONES DEPORTIVAS ISIDORO, S.L.',
#        'PISCINAS MUNDO ACUATICO, S.L.', 'ABC GRANOLLERS, S.L.',
#        'CUESTA LAMO, JESUS ROMAN', 'ITALIA LOPEZ CABALLERO, S.L.',
#        'BLANCO JAVARES, CARLOS',
#        'CONSERVACIÓN MAQUINARIA INDUSTRIAL, SLU', 'ISLA MEDINA, S.A.',
#        'CONSAN PISCINAS,S.L.', 'SERTEC AGROJARDIN S.L.', 'MUNDIAGUA,S.L.',
#        'AGUAS CANARIAS I+D, S.L.', 'SALTOKI LOGISTICA VALENCIA SL',
#        'FERRETERIA GARCIA Y CAVA S.L',
#        'ZABALETA EXCLUSIVAS SANITARIAS,S.L.',
#        'CANALIZACIONES Y FERRETERIA DIMAS S.L.L.',
#        'INTERMAR MANT.DE PISCINES I JARDINS,S.L.', 'MATIVER S.L.',
#        'AQUADREAMS ATLANTIC, SL', 'GRUPO ROULEAUX, S.L',
#        'FERROTORRES, S.L.', 'NORAPLAS SEMIELABORADOS S.L.',
#        'ATAGUA, S.L.', 'PINTURAS BROGERAS, S.L.',
#        'STEELSER TECHNICAL GROUP & SOLUT.,S.L.', 'MG TEMPOCLEANER, S.L.',
#        'POLIESTER DIEGO S.L.', 'TALBORA, S.L.',
#        'SUMINISTROS SPLASH 7, S.L.', 'COLOMA DELGAR, CARLA',
#        'PISCINAS OASIS, S.L.', 'BUENO MANZANO, JUSTO', 'JELOAL, S.A.U',
#        'ALONSO BORREGO, JAVIER', 'CLAVIA ONLINE 845, S.L.',
#        'ELECTROBOMBAS ARANDA S.L.', 'VEMARGALICIA, S.L.',
#        'QUIMIPOOL PISC.Y JARDINES S.L.', 'GREENS CENTER PALACIOS, S.L.',
#        'DISTRIBUCIONES ENELCA JAEN, S.L.',
#        'SOLUC.INTEG.EFIC.Y TECN.EDIF.SL (SV)',
#        'TU ALMACEN DEL CLIMA, S.L.', 'REGS SAGUNT S.L.',
#        'SUIMPLAST MATERIALS, S.L.', 'SUMINISTROS LA MURALLA S.L.',
#        'PMS SAYMI SURESTE S.L.', 'ELECTRO PLA GRANOLLERS, S.A.',
#        'TERMOCLUB, S.A.', 'LINEAL TERMES, S.L.',
#        'FUNDACIÓN DIOCESANA RAMON LLULL - SJOII',
#        'FERRETERIA MERIDA 4G S.L.L.', 'GALEKTRA XXI S.L.',
#        'VAZQUEZ GONZALEZ, MARCOS', 'SANTAMARIA SANCHA, OSCAR',
#        "FERRETERIA C'AN MANOLO DE CALA PI, S.L.",
#        'COMPONENTES DEL CALOR S.L.', 'SERTYMAN, S.C.L.',
#        'TECNOSOL S.C.L.', 'HERMANOS SIMO S.L.', 'PISCINAS PITIUSAS, S.L.',
#        'TEICAN MEDIOAMBIENTAL, S.L.', 'VALVULERIA Y SANEAMIENTOS S.L.',
#        'ELECTRICIDAD GORGOSO, S.L.', 'OSUNA CARRACEDO, SERGIO',
#        'HIDROIN, S.L.', 'POLIESTER Y ACEROS VILLARROBLEDO S.L',
#        'CRUZ PEREZ-BUSTOS S.L.', 'HIMARCAN TEC.AGUA Y CLIMA,SLU',
#        'EMPRESA TECNICA DE GESTION DEPORTIVA,SL.',
#        'REPUESTOS AGRICOLAS ROMAN, S.L.', 'FERRETERIA KOBEL S.L.',
#        'ORTIGOSA MARTI, JORDI', 'AGROJARDIN JULIAN, S.L.',
#        'A-KROLL PROYECTOS INTEGRALES, S.L.', 'BURGOS BURGOS, ERNESTO',
#        'HERRAIZ SISTEMES, S.A.', 'SUMINISTROS Y PINTURAS EL TRINI S.L',
#        'HIDRO-VINISA, S.L.', 'JALAJE S.L.', 'SUDIFONT, S.L.',
#        'JOSE ABRIL E HIJOS, S.L.', 'PISCINAS GALLAECIA S.L.',
#        'IBR PISCINAS, S.L.'], dtype=object)

# %%
df["Customer name"] = df["Customer name"].str.replace(r' - 100', '')
df["Customer name"] = df["Customer name"].str.replace(r'(?!-)[^\w\s]', '', regex=True)
df["Customer name"] = df["Customer name"].str.replace('Ã‘', 'A')
df["Customer name"] = df["Customer name"].str.replace('Ã“', 'A')
df["Customer name"] = df["Customer name"].str.replace(r'[^\x00-\x7f]', '', regex=True)
df["Customer name"] = df["Customer name"].str.strip()

# %%
df2 = df[['Purchase Date', 'Customer name', 'Global Amount']]
df2
# Out:
#              Purchase Date                            Customer name  \
# 0      2023-01-02 00:00:00   SUMINISTROS DE FONTANERIA CASTELLON SL
# 1      2023-01-02 00:00:00         CLIMAPOOL INSULAR SLU LAS PALMAS
# 2      2023-01-02 00:00:00                       MM 2004 SERDEMA SL
# 3      2023-01-02 00:00:00       ITESA PROYECTOS E INSTALACIONES SL
# 4      2023-01-02 00:00:00  NOVA RECAL SERVICIOS Y MANTENIMIENTO SL
# ...                    ...                                      ...
# 16035  2023-06-30 00:00:00                 SANEAMIENTOS AXARQUIA SL
# 16036  2023-06-30 00:00:00                        FIBRAGUA ISLEA SL
# 16037  2023-06-30 00:00:00                           FUTURQUIMIA SL
# 16038  2023-06-30 00:00:00           AC PISCINA REFORMA Y JARDIN SL
# 16039  2023-06-30 00:00:00                        RIEGOS MANACOR SL
#
#        Global Amount
# 0             639.95
# 1            6077.00
# 2            1399.25
# 3             237.51
# 4             793.10
# ...              ...
# 16035          72.90
# 16036         593.78
# 16037         383.55
# 16038          53.84
# 16039        1194.54
#
# [16040 rows x 3 columns]

# %%
df2["Purchase Date"] = pd.to_datetime(df2["Purchase Date"])
df2['Global Amount'] = pd.to_numeric(df2['Global Amount'])
# Out:
# /var/folders/yx/wg0v7ck91t14mxp5lfptvbh00000gn/T/ipykernel_5434/501058408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Purchase Date"] = pd.to_datetime(df2["Purchase Date"])
# /var/folders/yx/wg0v7ck91t14mxp5lfptvbh00000gn/T/ipykernel_5434/501058408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Global Amount'] = pd.to_numeric(df2['Global Amount'])

# %%
df2.dtypes
# Out:
# Purchase Date    datetime64[ns]
# Customer name            object
# Global Amount           float64
# dtype: object

# %%
snapshot_date = df2['Purchase Date'].max() + timedelta(days=1)

# %%
df3 = df2.groupby('Customer name').agg({'Global Amount': ['sum','count'], 'Purchase Date': lambda x: (snapshot_date - x.max()).days}).reset_index()

# %%
df3.head(3)
# Out:
#             Customer name Global Amount       Purchase Date
#                                     sum count      <lambda>
# 0  A  M INFINITY POOLS SL      14463.90     1           173
# 1    A CAMPIA DE LEMOS SL       7677.60     1           100
# 2           A PALLISER SL       2362.59     7            29

# %%
df3.columns
# Out:
# MultiIndex([('Customer name',         ''),
#             ('Global Amount',      'sum'),
#             ('Global Amount',    'count'),
#             ('Purchase Date', '<lambda>')],
#            )

# %%
df4 = df3.rename(columns={'': 'Customer Name',
                          "sum": "Monetary value",
                          'count': 'Frequency',
                          '<lambda>': 'Recency'})

# %%
# Dropping 1st level Index:
df4.columns = df4.columns.droplevel(0)

# %%
df4.head(3)
# Out:
#             Customer Name  Monetary value  Frequency  Recency
# 0  A  M INFINITY POOLS SL        14463.90          1      173
# 1    A CAMPIA DE LEMOS SL         7677.60          1      100
# 2           A PALLISER SL         2362.59          7       29

# %%
df4.to_excel(f"./{month}/ES/RFM_ES_{month}.xlsx", index=False)
